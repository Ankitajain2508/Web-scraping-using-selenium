# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# importing all the required libraries

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome(r"C:\Users\OTP\Desktop\FlipRobo Internship\chromedriver_win32\chromedriver.exe")

# %% [markdown]
# # Question 1

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
# opening HTML link on automated test software window using driver.get
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME, "suggestor-input")
designation.send_keys('Data Analyst')

loc =driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
loc.send_keys ("Bangalore")

search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

job_title =[]
job_location =[]
company_name =[]
experience_required = []

title = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title[0:10]:
    job_title.append(i.text)
location = driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi location"]')
for j in location [0:10]:
    job_location.append(j.text)
name = driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for k in name [0:10]:
    company_name.append(k.text)
experience = driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for l in experience [0:10]:
    experience_required.append(l.text)
    
# print(len(job_title), len(job_location), len(company_name), len(experience_required)

df=pd.DataFrame({'Job Title':job_title,'Job Location':job_location,'Company Name':company_name,'Experience Required':experience_required})
df[:10]
# Out:
# Empty DataFrame
# Columns: [Job Title, Job Location, Company Name, Experience Required]
# Index: []

# %% [markdown]
# # Question 2

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver.get("https://www.naukri.com/")

# %%
# entering the designation and the location 

title1= driver.find_element(By.CLASS_NAME, "suggestor-input")
title1.send_keys('Data Scientist')
loc1 =driver.find_element(By.XPATH, "/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
loc1.send_keys ("Bangalore")
search1 = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search1.click()

# %%
job_title1=[]
job_location1 =[]
company_name1 =[]

title2=driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for j in title2 [0:10]:
    job_title1.append(j.text)
# job_title1

location2=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi location"]')
for l in location2 [0:10]:
    job_location1.append(l.text)
# job_location1

name2=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for n in name2 [0:10]:
    company_name1.append(n.text)
# company_name1

# print(len(job_title1), len(job_location1), len(company_name1))

df=pd.DataFrame({'Job Title':job_title1, 'Job Location': job_location1, 'Company Name':company_name1 })
df
# Out:
#                                            Job Title  \
# 0                   Analystics & Modeling Specialist
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                               Manager-Data Science
# 4                                     Data Scientist
# 5                                Data Scientist - II
# 6                              Senior Data Scientist
# 7   ACN - Applied Intelligence - Data Scientist - 09
# 8  Python Programming Language Data Science Pract...
# 9  ACN - Applied Intelligence - C4DI - Sustainabi...
#
#                                         Job Location      Company Name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...         Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...       Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune     Tech Mahindra
# 3                                Bangalore/Bengaluru  AMERICAN EXPRESS
# ...

# %% [markdown]
# # Question 3

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
driver.get("https://www.naukri.com/")

title2 = driver.find_element(By.CLASS_NAME, 'suggestor-input')
title2.send_keys('Data Analyst')

search2= driver.find_element(By.CLASS_NAME, "qsbSubmit")
search2.click()

# %%
location3 = driver.find_element(By.XPATH, '/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[4]/div[2]/div[2]/label/i')
location3.click()

# %%
salary1 = driver.find_element(By.XPATH, '/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i')
salary1.click()

# %%
job_title2=[]
job_location2 =[]
company_name2 =[]
exp_required2 = []

title3=driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title3 [0:10]:
    job_title2.append(i.text)
job_title2

name3=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in name3 [0:10]:
    company_name2.append(i.text)
company_name2

loc2=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc2 [0:10]:
    job_location2.append(i.text)
job_location2

exp2=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp2 [0:10]:
    exp_required2.append(i.text)
exp_required2

# print(len(job_title2), len(job_location2), len(company_name2), len(exp_required2))

df=pd.DataFrame({'Job Title':job_title2, 'Job Location': job_location2, 'Company Name':company_name2,'Experience Required': exp_required2})
df
# Out:
#                                            Job Title  \
# 0                                       Data Analyst
# 1                                       Data Analyst
# 2                 Healthcare Research & Data Analyst
# 3                                       Data Analyst
# 4                            HR Data Analyst | Noida
# 5  Data Analyst| Boutique strategy research compa...
# 6                                Senior Data Analyst
# 7                 MIS Executive /Data Analyst /Delhi
# 8                                    Sr Data Analyst
# 9                                       Data Analyst
#
#                                         Job Location  \
# 0           Delhi / NCR, New Delhi, Gurgaon/Gurugram
# 1  Delhi / NCR, Kolkata, Indore, Hyderabad/Secund...
# 2                                   Gurgaon/Gurugram
# 3                                              Noida
# 4                                              Noida
# 5                 Noida, New Delhi, Gurgaon/Gurugram
# ...

# %% [markdown]
# # Question 4

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand 2. Product Description 3. Price 4. Discount
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses.

# %%
driver.get('https://www.flipkart.com/')

# %%
popup=driver.find_element(By.XPATH, '/html/body/div[2]/div/div/button')
popup.click()

# %%
product=driver.find_element(By.CLASS_NAME, '_3704LK')
product.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME, 'L0Z3Pu')
search.click()

# %%
brand_name=[]
product_description=[]
price=[]
discount=[]

# start=0
# stop=3

for page in range(4):
    
    brand=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for b in brand:
        brand_name.append(b.text)

    product=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for p in product:
        product_description.append(p.text)

    value=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for v in value:
        price.append(v.text)
    disc=driver.find_elements(By.XPATH, '//div[@class="_3Ay6Sb"]')
    for d in disc:
        discount.append(d.text)

#     next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
#     next_button.click()
#     time.sleep(3)

print(len(brand_name), len(product_description), len(price), len(discount))

df=pd.DataFrame({'Brand Name': brand_name,'Product Description':product_description,'Price': price,'Discount':discount})
df[:100]
# Out:
# 160 160 160 160
#         Brand Name                                Product Description Price  \
# 0     hayden haiza   Polarized, UV Protection Aviator Sunglasses (55)  ₹413
# 1     Silver Kartz           UV Protection Clubmaster Sunglasses (53)  ₹278
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹599
# 3        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹149
# 4         Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹489
# ..             ...                                                ...   ...
# 95            SRPM             UV Protection Wayfarer Sunglasses (50)  ₹149
# 96  ROZZETTA CRAFT              UV Protection Aviator Sunglasses (55)  ₹649
# 97  ROZZETTA CRAFT   Polarized, UV Protection Aviator Sunglasses (55)  ₹497
# 98        Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹539
# 99       New Specs   UV Protection Rectangular Sunglasses (Free Size)  ₹259
#
#    Discount
# 0   83% off
# ...

# %% [markdown]
# # Question 5

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product- reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market')

# %%
rating=[]
review_summary=[]
full_review=[]

for page in range(10):
    ratings=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in ratings:
        rating.append(i.text)

    review=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for j in review:
        review_summary.append(j.text)
        
    full=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for k in full:
        full_review.append(k.text)
        
# print(len(rating),len(review_summary),len(full_review))

df=pd.DataFrame({'Ratings':rating,'Review Summary':review_summary,'Full Review':full_review})
df[:100]
# Out:
#    Ratings       Review Summary  \
# 0        5       Simply awesome
# 1        5     Perfect product!
# 2        5  Best in the market!
# 3        4      Value-for-money
# 4        5    Worth every penny
# ..     ...                  ...
# 95       5   Highly recommended
# 96       5   Highly recommended
# 97       5     Perfect product!
# 98       4          Pretty good
# 99       5        Great product
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  It's my first time to use iOS phone and I am l...
# 96  What a camera .....just awesome ..you can feel...
# 97  Value for money\n5 star rating\nExcellent came...
# ...

# %% [markdown]
# # Question 6

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand 2. Product Description 3. Price
#
# As shown in the below image, you have to scrape the tick marked attributes.

# %%
driver.get('https://www.flipkart.com/')

# %%
product=driver.find_element(By.CLASS_NAME, '_3704LK')
product.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME, 'L0Z3Pu')
search.click()

# %%
brand_name4=[]
product_description4=[]
price4=[]
discount4=[]

for page in range(4):
    
    brands=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for b in brands:
        brand_name4.append(b.text)

    products=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for p in products:
        product_description4.append(p.text)

    values=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for v in values:
        price4.append(v.text)
    discounts=driver.find_elements(By.XPATH, '//div[@class="_3Ay6Sb"]')
    for d in discounts:
        discount4.append(d.text)

# print(len(brand_name4), len(product_description4), len(price4), len(discount4))

df=pd.DataFrame({'Brand Name': brand_name4,'Product Description':product_description4,'Price': price4,'Discount':discount4})
df[:100]
# Out:
#    Brand Name                                Product Description   Price  \
# 0          TR  Running / Walking / Sport Shoes For Men Sneake...    ₹494
# 1     edisson    Casuals shoe for Men's (white) Sneakers For Men    ₹559
# 2      Labbin                                   Sneakers For Men    ₹399
# 3         SFR  PLANCK Smart Grey Lace-Ups Casuals Sneakers Sn...    ₹209
# 4        aadi  Mesh | Ultralightweight | Comfortable | Breath...    ₹359
# ..        ...                                                ...     ...
# 95        SFR                                   Sneakers For Men    ₹269
# 96       PUMA           Skye Clean Distressed Sneakers For Women  ₹2,009
# 97     Layasa      Stylish Casual Sports Shoe Sneakers For Women    ₹489
# 98        SFR  PLANCK Smart Red Lace-Ups Casuals Sneakers Sne...    ₹209
# 99  Deals4you                                 Sneakers For Women    ₹299
#
#    Discount
# 0   67% off
# 1   72% off
# 2   60% off
# 3   65% off
# 4   82% off
# ...

# %% [markdown]
# # Question 7

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver.get('https://www.amazon.in/')

# %%
product=driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
product.send_keys('laptop')

search=driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
cpu = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[14]/span/a/div/label/i')
cpu.click()

# %%
title5=[]
ratings5=[]
price5=[]

    
brands1=driver.find_elements(By.XPATH, '//span[@class="a-size-medium a-color-base a-text-normal"]')
for b in brands1[:10]:
    title5.append(b.text)
title5

ratings1=driver.find_elements(By.XPATH, '//span[@class="a-size-base"]')
for r in ratings1[:10]:
    ratings5.append(r.text)
ratings5

prices1=driver.find_elements(By.XPATH, '//span[@class="a-price-whole"]')
for p in prices1[:10]:
    price5.append(p.text)


# print(len(title5), len(ratings5), len(price5))
print("Dataframe of 10 Brands with their prices and ratings")

df=pd.DataFrame({'Brand Title': title5,'Product Ratings':ratings5,'Price': price5})
df[:10]
# Out:
# Dataframe of 10 Brands with their prices and ratings
#                                          Brand Title Product Ratings     Price
# 0  Acer Swift 5 Intel Evo Premium 14 Inches Full ...           (4.2)  1,05,385
# 1  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...           (3.9)    57,990
# 2  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...           (4.0)    95,546
# 3  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...           (4.2)    82,990
# 4  HP Victus Gaming Latest 12th Gen Intel Core i7...           (4.3)    82,490
# 5  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...           (4.2)    89,000
# 6  Acer Nitro 5 Gaming Laptop Intel core i7 11th ...           (3.9)    79,990
# 7  ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms...           (5.0)  1,49,900
# 8  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...           (3.3)    24,935
# 9  HP Pavilion x360 11th Gen Intel Core i7 14 inc...           (4.4)    82,490

# %% [markdown]
# # Question 8

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpage https://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
# opening HTML link on automated test software window using driver.get
driver.get("https://www.azquotes.com/")

quotes=driver.find_element(By.XPATH, "/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
quotes.click()

# %%
quote=[]
author=[]
category=[]

for page in range(10):
    quote1=driver.find_elements(By.XPATH,'//a[@class="title"]')
    author1=driver.find_elements(By.XPATH,'//div[@class="author"]')
    category1=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for q in quote1:
        quote.append(q.text)
    for a in author1:
        author.append(a.text)
    for c in category1:
        category.append(c.text)
        
# print(len(quote),len(author),len(category))

print("Top 1000 Quotes Of All Time")
df=pd.DataFrame({"Quote":quote, "Author":author, "Type of Quotes":category})
df
# Out:
# Top 1000 Quotes Of All Time
#                                                  Quote                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# # Question 9

# %% [markdown]
# Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpage https://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make the DataFrame.

# %%
driver.get("https://www.jagranjosh.com/")

# %%
gk=driver.find_element(By.XPATH, '/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a')
gk.click()

# %%
pm=driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
pm.click()

# %%
name=[]
year=[]
term=[]
remarks=[]



names=driver.find_elements(By.XPATH,'//tbody/tr/td[2]')
for n in names[:18]:
    name.append(n.text)
# # name

years=driver.find_elements(By.XPATH,'//tbody/tr/td[3]')
for y in years[:18]:
    year.append(y.text)

terms=driver.find_elements(By.XPATH,'//tbody/tr/td[4]')
for t in terms[:18]:
    term.append(t.text.split('\n')[0])
# print(term)

remark=driver.find_elements(By.XPATH,'//tbody/tr/td[5]')
for r in remark[:18]:
    remarks.append(r.text)
    


df=pd.DataFrame({"Name of Prime Minister": name, "Born-Dead":year, "Term of Office":term, "Remarks":remarks })
df
# Out:
#          Name of Prime Minister     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                          Term of Office  \
# ...

# %% [markdown]
# # Question 10

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name ,Description and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on left side.
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data and make the dataframe

# %%
driver.get("https://www.motor1.com/")

car=driver.find_element(By.CLASS_NAME, "m1-hamburger-button")
car.click()

# %%
feature=driver.find_element(By.XPATH, "/html/body/div[4]/div[1]/div[3]/ul/li[5]/a")
feature.click()

# %%
exp=driver.find_element(By.XPATH, "/html/body/div[3]/div[8]/div/div[1]/div[1]/div[2]/div/div[1]/h3/a")
exp.click()

# %%
car_name=[]
description=[]
final_description=[]
price=[]




name=driver.find_elements(By.XPATH, '//h3[@class="subheader"]')
for i in name [0:50]:
    car_name.append(i.text)
# car_name

    
    
# desc=driver.find_elements(By.XPATH, '//p')
# for d in desc:
#      description.append(d.text)
# # for i in description[4:-6][0::2]:
# #     pricesplit=i.split(':')
# #     price.append(pricesplit[1])
# # # len(price)
    
# # len(price)

desc=driver.find_elements(By.XPATH, '//p')
for d in desc:
     description.append(d.text)
# the description list will contain the comma separated price and description . Now I have created 1 new list final_description
# where i will index out the description list by using extend function. since description is at odd position index, i have used
# [1::2] which will separate them out. Now the price is then extended from description list and extracted.
        
# description[4:-6][0::2]

final_description.extend(description[4:-6][1::2])

price.extend(description[4:-6][0::2])
# # # price
# # # len(price)


    
# # # len(price)



# # len(final_description)
# # # final_description
# # # value=driver.find_elements(By.XPATH,"//strong")
# # # for i in value [0:50]:
# # #     price.append(i.text)
# # #     while('' in price):
# # #         price.remove('')
# # # len(price)
# print(len(car_name), len(final_description), len(price))

df=pd.DataFrame({'Car Name':car_name, 'Description':final_description, 'Price':price})
df
# Out:
#                            Car Name  \
# 0                         Drako GTE
# 1                     De Tomaso P72
# 2                 Ferrari LaFerrari
# 3                     Pagani Huayra
# 4                      McLaren Elva
# 5                       Czinger 21C
# 6                     Ferrari Monza
# 7                Gordon Murray T.33
# 8                 Koenigsegg Gemera
# 9                       Zenvo TSR-S
# 10               Hennessey Venom F5
# 11                  Bentley Bacalar
# 12    Hispano Suiza Carmen Boulogne
# 13           Bentley Mulliner Batur
# 14                     Deus Vayanne
# 15                      SSC Tuatara
# 16                      Lotus Evija
# 17              Aston Martin Vulcan
# 18                       Delage D12
# 19                McLaren Speedtail
# 20                     Rimac Nevera
# 21                    Pagani Utopia
# 22             Pininfarina Battista
# 23                Ferrari FXX K Evo
# 24               Gordon Murray T.50
# ...
